# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
scrap_price = pd.read_csv("scrap price.csv")

# %%
scrap_price.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
scrap_price.shape
# Out:
# (205, 26)

# %%
scrap_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
scrap_price.describe()
# Out:
#                ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
scrap_price.drop("ID", inplace=True, axis = 1)

# %%
scrap_price.head()
# Out:
#    symboling                      name fueltypes aspiration doornumbers  \
# 0          3        alfa-romero giulia       gas        std         two
# 1          3       alfa-romero stelvio       gas        std         two
# 2          1  alfa-romero Quadrifoglio       gas        std         two
# 3          2               audi 100 ls       gas        std        four
# 4          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  carlength  ...  \
# 0  convertible         rwd          front       88.6      168.8  ...
# 1  convertible         rwd          front       88.6      168.8  ...
# 2    hatchback         rwd          front       94.5      171.2  ...
# 3        sedan         fwd          front       99.8      176.6  ...
# 4        sedan         4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
scrap_price.columns
# Out:
# Index(['symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
scrap_price.isnull().sum()
# Out:
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
scrap_price["name"].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
scrap_price["fueltypes"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
scrap_price.columns
# Out:
# Index(['symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
scrap_price.drop("name", axis = 1, inplace = True)

# %%
scrap_price.head()
# Out:
#    symboling fueltypes aspiration doornumbers      carbody drivewheels  \
# 0          3       gas        std         two  convertible         rwd
# 1          3       gas        std         two  convertible         rwd
# 2          1       gas        std         two    hatchback         rwd
# 3          2       gas        std        four        sedan         fwd
# 4          2       gas        std        four        sedan         4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
# ...

# %%
scrap_price["aspiration"].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
scrap_price["doornumbers"].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
scrap_price["carbody"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
scrap_price["enginelocation"].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
scrap_price["fuelsystem"].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
sns.displot(scrap_price["price"], bins = 30);

# %%
sns.jointplot(x="horsepower", y="price", data = scrap_price)

# %%
sns.jointplot(x="enginesize", y="price", data = scrap_price)

# %%
sns.jointplot(x="enginesize", y="horsepower", data = scrap_price)

# %%
scrap_price.head()
# Out:
#    symboling fueltypes aspiration doornumbers      carbody drivewheels  \
# 0          3       gas        std         two  convertible         rwd
# 1          3       gas        std         two  convertible         rwd
# 2          1       gas        std         two    hatchback         rwd
# 3          2       gas        std        four        sedan         fwd
# 4          2       gas        std        four        sedan         4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
# ...

# %%
sns.jointplot(x="carlength", y="price", data = scrap_price);

# %%
sns.jointplot(x="carwidth", y="price", data = scrap_price);

# %%
sns.jointplot(x="fueltypes", y="price", data = scrap_price);

# %%
sns.jointplot(x="carbody", y="price", data = scrap_price)

# %%
sns.jointplot(x="aspiration", y="price", data = scrap_price);

# %%
sns.jointplot(x="doornumbers", y="price", data = scrap_price);

# %%
sns.jointplot(x="drivewheels", y="price", data = scrap_price);

# %%
sns.jointplot(x="symboling", y="price", data = scrap_price);

# %%
scrap_price["symboling"].unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
scrap_price.drop("symboling", axis=1, inplace = True)

# %%
scrap_price.head()
# Out:
#   fueltypes aspiration doornumbers      carbody drivewheels enginelocation  \
# 0       gas        std         two  convertible         rwd          front
# 1       gas        std         two  convertible         rwd          front
# 2       gas        std         two    hatchback         rwd          front
# 3       gas        std        four        sedan         fwd          front
# 4       gas        std        four        sedan         4wd          front
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130       mpfi
# 1       88.6      168.8      64.1       48.8  ...         130       mpfi
# 2       94.5      171.2      65.5       52.4  ...         152       mpfi
# 3       99.8      176.6      66.2       54.3  ...         109       mpfi
# 4       99.4      176.6      66.4       54.3  ...         136       mpfi
#
#   boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
scrap_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltypes         205 non-null    object
#  1   aspiration        205 non-null    object
#  2   doornumbers       205 non-null    object
#  3   carbody           205 non-null    object
#  4   drivewheels       205 non-null    object
#  5   enginelocation    205 non-null    object
#  6   wheelbase         205 non-null    float64
#  7   carlength         205 non-null    float64
#  8   carwidth          205 non-null    float64
#  9   carheight         205 non-null    float64
#  10  curbweight        205 non-null    int64
#  11  enginetype        205 non-null    object
#  12  cylindernumber    205 non-null    object
#  13  enginesize        205 non-null    int64
#  14  fuelsystem        205 non-null    object
#  15  boreratio         205 non-null    float64
# ...

# %%
scrap_price["cylindernumber"].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
sns.jointplot(x="cylindernumber", y="price", data = scrap_price);

# %%
sns.jointplot(x="cylindernumber", y="horsepower", data = scrap_price);

# %%
a = scrap_price[scrap_price["cylindernumber"] == "twelve"].index

# %%
a
# Out:
# Int64Index([49], dtype='int64')

# %%
scrap_price.drop(a, inplace = True)

# %%
b = scrap_price[(scrap_price["cylindernumber"] == "eight") & (scrap_price["horsepower"] > 280)].index
b
# Out:
# Int64Index([129], dtype='int64')

# %%
scrap_price.drop(b, inplace = True)

# %%
c = scrap_price[(scrap_price["horsepower"] >160) & (scrap_price["price"] > 45000)].index
scrap_price.drop(c, inplace = True)

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
scrap_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltypes         202 non-null    object
#  1   aspiration        202 non-null    object
#  2   doornumbers       202 non-null    object
#  3   carbody           202 non-null    object
#  4   drivewheels       202 non-null    object
#  5   enginelocation    202 non-null    object
#  6   wheelbase         202 non-null    float64
#  7   carlength         202 non-null    float64
#  8   carwidth          202 non-null    float64
#  9   carheight         202 non-null    float64
#  10  curbweight        202 non-null    int64
#  11  enginetype        202 non-null    object
#  12  cylindernumber    202 non-null    object
#  13  enginesize        202 non-null    int64
#  14  fuelsystem        202 non-null    object
#  15  boreratio         202 non-null    float64
# ...

# %%
ct = make_column_transformer(
    (OneHotEncoder(handle_unknown="ignore"),
        ["fueltypes", "aspiration", "doornumbers", "carbody", "drivewheels",
         "enginelocation", "enginetype", "cylindernumber", "fuelsystem"])
    )

# %%
X = scrap_price.drop("price", axis = 1)
y = scrap_price["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train_transformed = ct.fit_transform(X_train)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train_transformed, y_train)
# Out:
# LinearRegression()

# %%
X_test_transformed = ct.transform(X_test)

# %%
lm.intercept_
# Out:
# 24552.166784080066

# %%
lm.coef_
# Out:
# array([    54.55570786,    -54.55570786,  -1816.60415259,   1816.60415259,
#           990.23549112,   -990.23549112,   2474.08041773,  -2565.55088828,
#           447.82374857,     59.17371349,   -415.52699152,  -1324.92090201,
#         -1315.83376131,   2640.75466332,  -6098.2189804 ,   6098.2189804 ,
#          1375.19723218,   1869.53636382,   2884.62277382,   1896.17420962,
#         -4993.62997237,  -3031.90060706,  18281.52924894,  -4608.54055142,
#        -10381.04934715,   -260.0387433 ,  -3031.90060706,   -215.79618343,
#          -914.61648561,  -1672.32968518,     54.55570786,   3027.67035278,
#          -142.77938399,   -136.70432243])

# %%
y_pred = lm.predict(X_test_transformed)

# %%
plt.scatter(y_test, y_pred)

# %%
o_pred = lm.predict(X_train_transformed)

# %%
plt.scatter(y_train, o_pred)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(y_test, y_pred, c = "g", label="Predictions")
plt.scatter(y_train, o_pred, c = "r", label="training")
plt.legend();

# %%
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# MAE:  2554.9541857506542

# %%
print("MSE: ", mean_squared_error(y_test, y_pred))
# Out:
# MSE:  14946563.536831774

# %%
print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE:  3866.0785735460386

# %% [markdown]
# #### Trying with scaler

# %%
scrap_price.head()
# Out:
#   fueltypes aspiration doornumbers      carbody drivewheels enginelocation  \
# 0       gas        std         two  convertible         rwd          front
# 1       gas        std         two  convertible         rwd          front
# 2       gas        std         two    hatchback         rwd          front
# 3       gas        std        four        sedan         fwd          front
# 4       gas        std        four        sedan         4wd          front
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130       mpfi
# 1       88.6      168.8      64.1       48.8  ...         130       mpfi
# 2       94.5      171.2      65.5       52.4  ...         152       mpfi
# 3       99.8      176.6      66.2       54.3  ...         109       mpfi
# 4       99.4      176.6      66.4       54.3  ...         136       mpfi
#
#   boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
scrap_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltypes         202 non-null    object
#  1   aspiration        202 non-null    object
#  2   doornumbers       202 non-null    object
#  3   carbody           202 non-null    object
#  4   drivewheels       202 non-null    object
#  5   enginelocation    202 non-null    object
#  6   wheelbase         202 non-null    float64
#  7   carlength         202 non-null    float64
#  8   carwidth          202 non-null    float64
#  9   carheight         202 non-null    float64
#  10  curbweight        202 non-null    int64
#  11  enginetype        202 non-null    object
#  12  cylindernumber    202 non-null    object
#  13  enginesize        202 non-null    int64
#  14  fuelsystem        202 non-null    object
#  15  boreratio         202 non-null    float64
# ...

# %%
cts = make_column_transformer(
    (MinMaxScaler(), ["horsepower", "peakrpm", "citympg", "highwaympg", "enginesize", "compressionratio"]),
    (OneHotEncoder(handle_unknown="ignore"),
        ["fueltypes", "aspiration", "doornumbers", "carbody", "drivewheels",
         "enginelocation", "enginetype", "cylindernumber", "fuelsystem"])
    )

# %%
Xs = scrap_price.drop("price", axis = 1)
ys = scrap_price["price"]

# %%
X_trains, X_tests, y_trains, y_tests = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train_transformeds = ct.fit_transform(X_trains)

# %%
lm.fit(X_train_transformeds, y_trains)
# Out:
# LinearRegression()

# %%
X_test_transformeds = ct.transform(X_tests)

# %%
y_preds = lm.predict(X_test_transformeds)

# %%
plt.scatter(y_tests, y_preds)

# %%
print("MAE: ", mean_absolute_error(y_tests, y_preds))
# Out:
# MAE:  2554.9541857506542
